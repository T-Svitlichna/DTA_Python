# %% [markdown]
# <a href="https://colab.research.google.com/github/T-Svitlichna/DTA_Python/blob/main/Lekcia/%D0%9B%D0%B5%D0%BA%D1%86%D1%96%D1%8F_18052026_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function Python
def name_func():
  pass

# %%
sum([1,3,7,4])
# Out:
# 15

# %%
def sum_namber()
  print(2+3)
sum_namber()
# Out:
#   File "/tmp/ipykernel_4485/2972660187.py", line 1
#     def sum_namber()
#                     ^
# SyntaxError: expected ':'

# %%
a = 2
b = 3
def sum_namber(a,b):
  print(a+b)
sum_namber(a,b) # зовнішні
# Out:
# 5

# %%
def num()
        c = 3

# локальна

# %%
a = 2
b = 3
def sum_namber(n1,n2):
    print(n1*n2)
sum_namber(a,b)
# Out:
# 6

# %%
#sum_namber(3+5)+5# так не працює

# %% [markdown]
# Типи результатів Функ

# %% [markdown]
# NonType

# %%
my_dact = {
    1: 'one',
    2:'two',
    3:'three',
    4:'four',
    5:'five',
    6:'six',
    7:'seven',
    8:'eight',
    9:'nine',
    0:'zero'
}

# %%
def info(pz):
    print(pz)
type(info(my_dact))
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', 6: 'six', 7: 'seven', 8: 'eight', 9: 'nine', 0: 'zero'}
# NoneType

# %%
def info(pz):
   pz[6] = "six+"
   print(pz)
type(info(my_dact))
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', 6: 'six+', 7: 'seven', 8: 'eight', 9: 'nine', 0: 'zero'}
# NoneType

# %%
def sum_namber(a,b):
    print('виклик')
    return a+b

print(sum_namber(5,7))#12

print(type(sum_namber(5,7)))#<class 'int'>



sum_namber(5,7) + 12   #24
# Out:
# виклик
# 12
# виклик
# <class 'int'>
# виклик
# 24

# %%
my_dict = {
    1: 'one',
    2:'two',
    3:'three',
    4:'four',
    5:'five',
    6:'six',
    7:'seven',
    8:'eight',
    9:'nine',
    0:'zero'
}

# %%
def dit_val(pz,key):
    print(pz[key])
dit_val(my_dict,3)
# Out:
# three

# %%
def dit_val(pz,key):
    return pz[key]
print(type(dit_val(my_dict,3)))# easy type
print(dit_val(my_dict,3)+'444') #funktion
print(my_dict) #просто повідомлення
# Out:
# <class 'str'>
# three444
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', 6: 'six', 7: 'seven', 8: 'eight', 9: 'nine', 0: 'zero'}

# %%
def new_fun(d:dict, key:int)->str:
    return d[key]
new_fun("ffhh",3)
# Out:
# 'h'

# %%
def func(a,b):
         pass
func(a = 5, b=6)
