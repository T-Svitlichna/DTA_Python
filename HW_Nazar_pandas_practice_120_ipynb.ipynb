# %% [markdown]
# <a href="https://colab.research.google.com/github/T-Svitlichna/DTA_Python/blob/main/HW_Nazar_pandas_practice_120_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas: практикум на 120 завдань
#
# **Тренування синтаксису • рівень: простий**
#
# ---
#
# Цей зошит містить **120 коротких завдань** на той функціонал pandas, який ми розглянули на лекції. Мета — набити руку на синтаксисі, щоб команди стали автоматичними.
#
# ## Дані
# Працюємо з даними онлайн-книгарні — файл `bookstore_sales.csv` (400 замовлень за 8 місяців).
#
# | Стовпець | Опис |
# |---|---|
# | `order_id` | Номер замовлення |
# | `date` | Дата замовлення |
# | `city` | Місто покупця |
# | `book_title` | Назва книги |
# | `genre` | Жанр |
# | `unit_price` | Ціна за одну книгу (грн) |
# | `quantity` | Кількість книг |
# | `discount_pct` | Знижка у відсотках |
# | `total` | Підсумкова сума замовлення (грн) |
# | `channel` | Канал замовлення (Сайт / Застосунок / Телефон) |
# | `manager` | Менеджер, що оформив замовлення |
# | `rating` | Оцінка покупця (3-5) |
#
# ## Як працювати
# - Запускайте кожну комірку (Shift + Enter)
# - Якщо забули синтаксис — підгляньте в notebook з лекції
# - Не бійтесь помилок, експериментуйте!
#
# ---

# %% [markdown]
# ## Підготовка
#
# Спочатку запустіть цю комірку — вона імпортує pandas і завантажує дані. Усі завдання працюють зі змінною `df`.

# %%
import pandas as pd

df = pd.read_csv("bookstore_sales.csv")
df.head()
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 3      5352  2024-08-18  Дніпро                 Sapiens      Наука
# 4      5032  2024-01-27    Київ            Шерлок Холмс   Детектив
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 3         410         1             0  410.0  Мобільний застосунок  Віктор
# 4         250         1            20  200.0                  Сайт    Олег
#
#    rating
# 0       5
# 1       5
# 2       5
# 3       3
# 4       3

# %% [markdown]
# ## Розділ 1. Перший погляд на дані (завдання 1-15)
#
# Команди: `head()`, `tail()`, `shape`, `columns`, `info()`, `describe()`, `dtypes`.

# %% [markdown]
# **Завдання 1.** Виведіть перші 5 рядків таблиці.

# %%
# Завдання 1:
df.head()
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 3      5352  2024-08-18  Дніпро                 Sapiens      Наука
# 4      5032  2024-01-27    Київ            Шерлок Холмс   Детектив
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 3         410         1             0  410.0  Мобільний застосунок  Віктор
# 4         250         1            20  200.0                  Сайт    Олег
#
#    rating
# 0       5
# 1       5
# 2       5
# 3       3
# 4       3

# %% [markdown]
# **Завдання 2.** Виведіть перші 10 рядків таблиці.
#
# > 💡 head() приймає число — скільки рядків показати.

# %%
# Завдання 2:
df.head(4)
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 3      5352  2024-08-18  Дніпро                 Sapiens      Наука
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 3         410         1             0  410.0  Мобільний застосунок  Віктор
#
#    rating
# 0       5
# 1       5
# 2       5
# 3       3

# %% [markdown]
# **Завдання 3.** Виведіть останні 5 рядків таблиці.
#
# > 💡 Скористайтесь методом tail().

# %%
# Завдання 3:
df.tail()
# Out:
#      order_id        date    city              book_title       genre  \
# 395      5043  2024-01-22   Львів                    Дюна  Фантастика
# 396      5129  2024-03-21  Харків                 Sapiens       Наука
# 397      5185  2024-04-22    Київ             Війна і мир     Історія
# 398      5336  2024-07-26   Львів  Гордість і упередження   Романтика
# 399      5048  2024-01-14   Одеса             Сила звички      Бізнес
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# 395         320         2             0   640.0  Мобільний застосунок   Ірина
# 396         410         5             5  1947.5                  Сайт    Олег
# 397         380         1             0   380.0  Мобільний застосунок   Ірина
# 398         240         3             0   720.0                  Сайт   Ірина
# 399         260         1             0   260.0  Мобільний застосунок   Ірина
#
#      rating
# 395       3
# 396       5
# 397       5
# 398       5
# ...

# %% [markdown]
# **Завдання 4.** Виведіть останні 3 рядки таблиці.

# %%
# Завдання 4:
df.tail(3)
# Out:
#      order_id        date   city              book_title      genre  \
# 397      5185  2024-04-22   Київ             Війна і мир    Історія
# 398      5336  2024-07-26  Львів  Гордість і упередження  Романтика
# 399      5048  2024-01-14  Одеса             Сила звички     Бізнес
#
#      unit_price  quantity  discount_pct  total               channel manager  \
# 397         380         1             0  380.0  Мобільний застосунок   Ірина
# 398         240         3             0  720.0                  Сайт   Ірина
# 399         260         1             0  260.0  Мобільний застосунок   Ірина
#
#      rating
# 397       5
# 398       5
# 399       3

# %% [markdown]
# **Завдання 5.** Дізнайтесь розмір таблиці (кількість рядків і стовпців).
#
# > 💡 Атрибут shape.

# %%
# Завдання 5:
df.shape
# Out:
# (400, 12)

# %% [markdown]
# **Завдання 6.** Виведіть тільки кількість рядків у таблиці.
#
# > 💡 shape[0] повертає перше число.

# %%
# Завдання 6:
df.shape[0]
# Out:
# 400

# %% [markdown]
# **Завдання 7.** Виведіть тільки кількість стовпців у таблиці.
#
# > 💡 shape[1].

# %%
# Завдання 7:
df.shape[1]
# Out:
# 12

# %% [markdown]
# **Завдання 8.** Виведіть назви всіх стовпців.
#
# > 💡 Атрибут columns.

# %%
# Завдання 8:
df.columns
# Out:
# Index(['order_id', 'date', 'city', 'book_title', 'genre', 'unit_price',
#        'quantity', 'discount_pct', 'total', 'channel', 'manager', 'rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# order_id          int64
# date             object
# city             object
# book_title       object
# genre            object
# unit_price        int64
# quantity          int64
# discount_pct      int64
# total           float64
# channel          object
# manager          object
# rating            int64
# dtype: object

# %% [markdown]
# **Завдання 9.** Виведіть загальну інформацію про таблицю (типи даних, кількість значень).
#
# > 💡 Метод info().

# %%
# Завдання 9:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      400 non-null    int64
#  1   date          400 non-null    object
#  2   city          400 non-null    object
#  3   book_title    400 non-null    object
#  4   genre         400 non-null    object
#  5   unit_price    400 non-null    int64
#  6   quantity      400 non-null    int64
#  7   discount_pct  400 non-null    int64
#  8   total         400 non-null    float64
#  9   channel       400 non-null    object
#  10  manager       400 non-null    object
#  11  rating        400 non-null    int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 37.6+ KB

# %% [markdown]
# **Завдання 10.** Виведіть статистику по числових стовпцях (середнє, мін, макс тощо).
#
# > 💡 Метод describe().

# %%
# Завдання 10:
df.describe()
# Out:
#           order_id  unit_price   quantity  discount_pct        total  \
# count   400.000000  400.000000  400.00000    400.000000   400.000000
# mean   5200.500000  283.350000    2.05750      2.500000   572.005000
# std     115.614301   86.900268    1.16945      5.142091   398.019126
# min    5001.000000  150.000000    1.00000      0.000000   128.000000
# 25%    5100.750000  220.000000    1.00000      0.000000   289.500000
# 50%    5200.500000  270.000000    2.00000      0.000000   450.000000
# 75%    5300.250000  350.000000    3.00000      0.000000   765.000000
# max    5400.000000  450.000000    5.00000     20.000000  2250.000000
#
#            rating
# count  400.000000
# mean     4.255000
# std      0.707975
# min      3.000000
# 25%      4.000000
# 50%      4.000000
# 75%      5.000000
# max      5.000000

# %%
df.describe(include="object")
# Out:
#               date    city              book_title  genre  channel manager
# count          400     400                     400    400      400     400
# unique         198       5                      15      8        3       5
# top     2024-01-03  Харків  Гордість і упередження  Наука  Телефон   Софія
# freq             5      98                      34     61      141      89

# %% [markdown]
# **Завдання 11.** Виведіть типи даних кожного стовпця.
#
# > 💡 Атрибут dtypes.

# %%
# Завдання 11:
df.dtypes
# Out:
# order_id          int64
# date             object
# city             object
# book_title       object
# genre            object
# unit_price        int64
# quantity          int64
# discount_pct      int64
# total           float64
# channel          object
# manager          object
# rating            int64
# dtype: object

# %% [markdown]
# **Завдання 12.** Виведіть перші 7 рядків таблиці.

# %%
# Завдання 12:
df.head(7)
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 3      5352  2024-08-18  Дніпро                 Sapiens      Наука
# 4      5032  2024-01-27    Київ            Шерлок Холмс   Детектив
# 5      5137  2024-03-06  Харків         Маленький принц     Дитяча
# 6      5022  2024-01-24    Київ            Лісова пісня     Поезія
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 3         410         1             0  410.0  Мобільний застосунок  Віктор
# ...

# %% [markdown]
# **Завдання 13.** Виведіть останні 10 рядків таблиці.

# %%
# Завдання 13:
df.tail(10)
# Out:
#      order_id        date    city              book_title       genre  \
# 390      5027  2024-01-17  Харків            Лісова пісня      Поезія
# 391      5085  2024-02-08   Одеса            Шерлок Холмс    Детектив
# 392      5333  2024-07-05  Дніпро             Сила звички      Бізнес
# 393      5341  2024-07-17   Львів         Маленький принц      Дитяча
# 394      5191  2024-04-05   Львів             Війна і мир     Історія
# 395      5043  2024-01-22   Львів                    Дюна  Фантастика
# 396      5129  2024-03-21  Харків                 Sapiens       Наука
# 397      5185  2024-04-22    Київ             Війна і мир     Історія
# 398      5336  2024-07-26   Львів  Гордість і упередження   Романтика
# 399      5048  2024-01-14   Одеса             Сила звички      Бізнес
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# 390         150         1             0   150.0                  Сайт   Софія
# ...

# %% [markdown]
# **Завдання 14.** Скільки всього значень (рядків) у таблиці? Використайте функцію len().

# %%
# Завдання 14:
len(df)
print("In this Table is ", len(df), "rows")
# Out:
# In this Table is  400 rows

# %% [markdown]
# **Завдання 15.** Виведіть перший рядок таблиці.
#
# > 💡 head(1).

# %%
# Завдання 15:
df.head(1)
# Out:
#    order_id        date    city book_title  genre  unit_price  quantity  \
# 0      5275  2024-06-25  Харків    Sapiens  Наука         410         2
#
#    discount_pct  total  channel manager  rating
# 0             0  820.0  Телефон   Ірина       5

# %% [markdown]
# ## Розділ 2. Вибір стовпців (завдання 16-30)
#
# Вибір одного стовпця: `df["col"]`. Вибір кількох: `df[["col1", "col2"]]`.

# %% [markdown]
# **Завдання 16.** Виведіть стовпець `city`.

# %%
# Завдання 16:
df["city"]
# Out:
# 0      Харків
# 1       Одеса
# 2      Харків
# 3      Дніпро
# 4        Київ
#         ...
# 395     Львів
# 396    Харків
# 397      Київ
# 398     Львів
# 399     Одеса
# Name: city, Length: 400, dtype: object

# %% [markdown]
# **Завдання 17.** Виведіть стовпець `total`.

# %%
# Завдання 17:
df["total"]
# Out:
# 0       820.0
# 1       480.0
# 2       204.0
# 3       410.0
# 4       200.0
#         ...
# 395     640.0
# 396    1947.5
# 397     380.0
# 398     720.0
# 399     260.0
# Name: total, Length: 400, dtype: float64

# %% [markdown]
# **Завдання 18.** Виведіть стовпець `book_title`.

# %%
# Завдання 18:
df["book_title"]
# Out:
# 0                     Sapiens
# 1      Гордість і упередження
# 2      Гордість і упередження
# 3                     Sapiens
# 4                Шерлок Холмс
#                 ...
# 395                      Дюна
# 396                   Sapiens
# 397               Війна і мир
# 398    Гордість і упередження
# 399               Сила звички
# Name: book_title, Length: 400, dtype: object

# %% [markdown]
# **Завдання 19.** Виведіть стовпці `city` та `total` разом.
#
# > 💡 Подвійні дужки: df[["city", "total"]].

# %%
# Завдання 19:
df[["city","total"]]
# Out:
#        city   total
# 0    Харків   820.0
# 1     Одеса   480.0
# 2    Харків   204.0
# 3    Дніпро   410.0
# 4      Київ   200.0
# ..      ...     ...
# 395   Львів   640.0
# 396  Харків  1947.5
# 397    Київ   380.0
# 398   Львів   720.0
# 399   Одеса   260.0
#
# [400 rows x 2 columns]

# %% [markdown]
# **Завдання 20.** Виведіть стовпці `book_title`, `genre` та `unit_price`.

# %%
# Завдання 20:
df[["book_title","genre","unit_price"]]
# Out:
#                  book_title       genre  unit_price
# 0                   Sapiens       Наука         410
# 1    Гордість і упередження   Романтика         240
# 2    Гордість і упередження   Романтика         240
# 3                   Sapiens       Наука         410
# 4              Шерлок Холмс    Детектив         250
# ..                      ...         ...         ...
# 395                    Дюна  Фантастика         320
# 396                 Sapiens       Наука         410
# 397             Війна і мир     Історія         380
# 398  Гордість і упередження   Романтика         240
# 399             Сила звички      Бізнес         260
#
# [400 rows x 3 columns]

# %% [markdown]
# **Завдання 21.** Виведіть перші 5 рядків стовпця `genre`.
#
# > 💡 Можна поєднати: df["genre"].head().

# %%
# Завдання 21:
df["genre"].head()
# Out:
# 0        Наука
# 1    Романтика
# 2    Романтика
# 3        Наука
# 4     Детектив
# Name: genre, dtype: object

# %% [markdown]
# **Завдання 22.** Виведіть стовпці `manager` та `total`, лише перші 10 рядків.

# %%
# Завдання 22:
df[["manager","total"]].head(10)
# Out:
#   manager  total
# 0   Ірина  820.0
# 1   Ірина  480.0
# 2   Ірина  204.0
# 3  Віктор  410.0
# 4    Олег  200.0
# 5    Олег  320.0
# 6    Олег  300.0
# 7  Наталя  405.0
# 8   Софія  855.0
# 9   Софія  180.0

# %% [markdown]
# **Завдання 23.** Виведіть стовпець `rating`.

# %%
# Завдання 23:
df[["rating"]]
# Out:
#      rating
# 0         5
# 1         5
# 2         5
# 3         3
# 4         3
# ..      ...
# 395       3
# 396       5
# 397       5
# 398       5
# 399       3
#
# [400 rows x 1 columns]

# %% [markdown]
# **Завдання 24.** Виведіть стовпці `order_id`, `date` та `city`.

# %%
# Завдання 24:
df[["order_id","date","city"]]
# Out:
#      order_id        date    city
# 0        5275  2024-06-25  Харків
# 1        5386  2024-08-09   Одеса
# 2        5100  2024-02-21  Харків
# 3        5352  2024-08-18  Дніпро
# 4        5032  2024-01-27    Київ
# ..        ...         ...     ...
# 395      5043  2024-01-22   Львів
# 396      5129  2024-03-21  Харків
# 397      5185  2024-04-22    Київ
# 398      5336  2024-07-26   Львів
# 399      5048  2024-01-14   Одеса
#
# [400 rows x 3 columns]

# %% [markdown]
# **Завдання 25.** Виведіть перші 3 рядки стовпців `book_title` та `quantity`.

# %%
# Завдання 25:
df[["book_title","quantity"]].head(3)
# Out:
#                book_title  quantity
# 0                 Sapiens         2
# 1  Гордість і упередження         2
# 2  Гордість і упередження         1

# %% [markdown]
# **Завдання 26.** Виведіть стовпець `channel`.

# %%
# Завдання 26:
df["channel"]
# Out:
# 0                   Телефон
# 1                   Телефон
# 2                      Сайт
# 3      Мобільний застосунок
# 4                      Сайт
#                ...
# 395    Мобільний застосунок
# 396                    Сайт
# 397    Мобільний застосунок
# 398                    Сайт
# 399    Мобільний застосунок
# Name: channel, Length: 400, dtype: object

# %% [markdown]
# **Завдання 27.** Виведіть стовпці `city`, `genre` та `total`, останні 5 рядків.
#
# > 💡 Поєднайте подвійні дужки і tail().

# %%
# Завдання 27:
df[["city","genre", "total"]].tail()
# Out:
#        city       genre   total
# 395   Львів  Фантастика   640.0
# 396  Харків       Наука  1947.5
# 397    Київ     Історія   380.0
# 398   Львів   Романтика   720.0
# 399   Одеса      Бізнес   260.0

# %% [markdown]
# **Завдання 28.** Виведіть стовпець `discount_pct`.

# %%
# Завдання 28:
df["discount_pct"]
# Out:
# 0       0
# 1       0
# 2      15
# 3       0
# 4      20
#        ..
# 395     0
# 396     5
# 397     0
# 398     0
# 399     0
# Name: discount_pct, Length: 400, dtype: int64

# %% [markdown]
# **Завдання 29.** Виведіть стовпці `unit_price` та `quantity`.

# %%
# Завдання 29:
df[["unit_price", "quantity"]]
# Out:
#      unit_price  quantity
# 0           410         2
# 1           240         2
# 2           240         1
# 3           410         1
# 4           250         1
# ..          ...       ...
# 395         320         2
# 396         410         5
# 397         380         1
# 398         240         3
# 399         260         1
#
# [400 rows x 2 columns]

# %% [markdown]
# **Завдання 30.** Виведіть стовпець `quantity`, перші 8 рядків.

# %%
# Завдання 30:
df["quantity"].head()
# Out:
# 0    2
# 1    2
# 2    1
# 3    1
# 4    1
# Name: quantity, dtype: int64

# %% [markdown]
# ## Розділ 3. Базові агрегати по стовпцю (завдання 31-50)
#
# Команди: `sum()`, `mean()`, `max()`, `min()`, `count()`, `unique()`, `nunique()`, `value_counts()`.

# %% [markdown]
# **Завдання 31.** Порахуйте загальну суму всіх замовлень (стовпець `total`).
#
# > 💡 df["total"].sum().

# %%
# Завдання 31:
df["total"].sum()
# Out:
# np.float64(228802.0)

# %% [markdown]
# **Завдання 32.** Порахуйте середню суму замовлення.
#
# > 💡 mean().

# %%
# Завдання 32:
print("AVG ", df["total"].mean())
# Out:
# AVG  572.005

# %% [markdown]
# **Завдання 33.** Знайдіть максимальну суму замовлення.
#
# > 💡 max().

# %%
# Завдання 33:
print("Max_ order_sum  =",df["total"].max())
# Out:
# Max_ order_sum  = 2250.0

# %% [markdown]
# **Завдання 34.** Знайдіть мінімальну суму замовлення.
#
# > 💡 min().

# %%
# Завдання 34:
print("Min_order: =",df["total"].min())
# Out:
# Min_order: = 128.0

# %% [markdown]
# **Завдання 35.** Порахуйте, скільки всього замовлень (використайте count() на будь-якому стовпці).

# %%
# Завдання 35:
df['order_id'].count()
# Out:
# np.int64(400)

# %% [markdown]
# **Завдання 36.** Знайдіть середню ціну книги (`unit_price`).

# %%
# Завдання 36:
df["unit_price"].mean()
# Out:
# np.float64(283.35)

# %% [markdown]
# **Завдання 37.** Знайдіть максимальну кількість книг у одному замовленні (`quantity`).

# %%
# Завдання 37:
df["quantity"].max()
# Out:
# 5

# %% [markdown]
# **Завдання 38.** Порахуйте загальну кількість проданих книг (сума стовпця `quantity`).

# %%
# Завдання 38:
df["quantity"].sum()
# Out:
# np.int64(823)

# %% [markdown]
# **Завдання 39.** Виведіть усі унікальні міста.
#
# > 💡 Метод unique().

# %%
# Завдання 39:
df["city"].unique()
# Out:
# array(['Харків', 'Одеса', 'Дніпро', 'Київ', 'Львів'], dtype=object)

# %% [markdown]
# **Завдання 40.** Виведіть усі унікальні жанри.

# %%
# Завдання 40:
df["genre"].unique()
# Out:
# array(['Наука', 'Романтика', 'Детектив', 'Дитяча', 'Поезія', 'Бізнес',
#        'Історія', 'Фантастика'], dtype=object)

# %% [markdown]
# **Завдання 41.** Скільки унікальних міст у даних?
#
# > 💡 Метод nunique().

# %%
# Завдання 41:
df["city"].nunique()
# Out:
# 5

# %% [markdown]
# **Завдання 42.** Скільки унікальних книг у даних?

# %%
# Завдання 42:
df["book_title"].nunique()
# Out:
# 15

# %% [markdown]
# **Завдання 43.** Скільки унікальних жанрів у даних?

# %%
# Завдання 43:
df["genre"].nunique()
# Out:
# 8

# %% [markdown]
# **Завдання 44.** Скільки замовлень з кожного міста? Використайте value_counts().
#
# > 💡 df["city"].value_counts().

# %%
# Завдання 44:
df["city"].value_counts()
# Out:
# city
# Харків    98
# Львів     83
# Одеса     82
# Дніпро    69
# Київ      68
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 45.** Скільки замовлень у кожному жанрі?
#
# > 💡 value_counts() на стовпці genre.

# %%
# Завдання 45:
df["genre"].value_counts()
# Out:
# genre
# Наука         61
# Бізнес        59
# Історія       52
# Поезія        51
# Фантастика    49
# Детектив      47
# Дитяча        47
# Романтика     34
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 46.** Скільки замовлень оформив кожен менеджер?

# %%
# Завдання 46:
df["manager"].value_counts()
# Out:
# manager
# Софія     89
# Олег      80
# Наталя    79
# Ірина     77
# Віктор    75
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 47.** Скільки замовлень через кожен канал (`channel`)?

# %%
# Завдання 47:
df["channel"].value_counts()
# Out:
# channel
# Телефон                 141
# Мобільний застосунок    135
# Сайт                    124
# Name: count, dtype: int64

# %% [markdown]
# **Завдання 48.** Виведіть усі унікальні значення оцінок (`rating`).

# %%
# Завдання 48:
df["rating"].unique()
# Out:
# array([5, 3, 4])

# %% [markdown]
# **Завдання 49.** Знайдіть середню оцінку (`rating`).

# %%
# Завдання 49:
df["rating"].mean()
# Out:
# np.float64(4.255)

# %% [markdown]
# **Завдання 50.** Знайдіть середню знижку (`discount_pct`).

# %%
# Завдання 50:
df["discount_pct"].mean()
# Out:
# np.float64(2.5)

# %% [markdown]
# ## Розділ 4. Фільтрація — одна умова (завдання 51-70)
#
# Принцип: `df[df["стовпець"] умова]`. Наприклад, `df[df["total"] > 500]`.

# %% [markdown]
# **Завдання 51.** Виведіть усі замовлення з міста Київ.
#
# > 💡 df[df["city"] == "Київ"].

# %%
# Завдання 51:
df[df["city"] == "Київ"]
# Out:
#      order_id        date  city                 book_title      genre  \
# 4        5032  2024-01-27  Київ               Шерлок Холмс   Детектив
# 6        5022  2024-01-24  Київ               Лісова пісня     Поезія
# 7        5139  2024-03-22  Київ               Лісова пісня     Поезія
# 14       5295  2024-06-12  Київ                Війна і мир    Історія
# 16       5102  2024-03-03  Київ               Шерлок Холмс   Детектив
# ..        ...         ...   ...                        ...        ...
# 375      5040  2024-01-25  Київ  Кладовище домашніх тварин   Детектив
# 376      5245  2024-05-18  Київ     Гордість і упередження  Романтика
# 378      5001  2024-01-08  Київ  Кладовище домашніх тварин   Детектив
# 384      5120  2024-03-23  Київ     Гордість і упередження  Романтика
# 397      5185  2024-04-22  Київ                Війна і мир    Історія
#
#      unit_price  quantity  discount_pct  total               channel manager  \
# ...

# %% [markdown]
# **Завдання 52.** Виведіть усі замовлення з міста Львів.

# %%
# Завдання 52:
df[df["city"] == "Львів"]
# Out:
#      order_id        date   city                 book_title       genre  \
# 9        5184  2024-04-24  Львів                     Кобзар      Поезія
# 10       5208  2024-05-13  Львів               Лісова пісня      Поезія
# 31       5297  2024-06-20  Львів  Кладовище домашніх тварин    Детектив
# 34       5158  2024-04-02  Львів  Кладовище домашніх тварин    Детектив
# 46       5373  2024-08-08  Львів              Атомні звички      Бізнес
# ..        ...         ...    ...                        ...         ...
# 386      5372  2024-08-24  Львів  Кладовище домашніх тварин    Детектив
# 393      5341  2024-07-17  Львів            Маленький принц      Дитяча
# 394      5191  2024-04-05  Львів                Війна і мир     Історія
# 395      5043  2024-01-22  Львів                       Дюна  Фантастика
# 398      5336  2024-07-26  Львів     Гордість і упередження   Романтика
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 53.** Виведіть усі замовлення з міста Одеса.

# %%
# Завдання 53:
df[df["city"] == "Одеса"]
# Out:
#      order_id        date   city                 book_title       genre  \
# 1        5386  2024-08-09  Одеса     Гордість і упередження   Романтика
# 11       5114  2024-03-21  Одеса            Квантова фізика       Наука
# 15       5325  2024-07-15  Одеса     Гордість і упередження   Романтика
# 18       5269  2024-06-20  Одеса               Лісова пісня      Поезія
# 21       5194  2024-04-21  Одеса                       1984  Фантастика
# ..        ...         ...    ...                        ...         ...
# 371      5266  2024-06-12  Одеса               Шерлок Холмс    Детектив
# 372      5116  2024-03-14  Одеса  Кладовище домашніх тварин    Детектив
# 377      5110  2024-03-27  Одеса                       1984  Фантастика
# 391      5085  2024-02-08  Одеса               Шерлок Холмс    Детектив
# 399      5048  2024-01-14  Одеса                Сила звички      Бізнес
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 54.** Виведіть усі замовлення жанру `Фантастика`.

# %%
# Завдання 54:
df[df["genre"] == "Фантастика"].head()
# Out:
#     order_id        date    city book_title       genre  unit_price  quantity  \
# 20      5165  2024-04-14  Харків       Дюна  Фантастика         320         5
# 21      5194  2024-04-21   Одеса       1984  Фантастика         280         1
# 33      5288  2024-06-10    Київ       1984  Фантастика         280         4
# 37      5382  2024-08-02    Київ       1984  Фантастика         280         1
# 43      5346  2024-07-03  Дніпро       Дюна  Фантастика         320         1
#
#     discount_pct   total               channel manager  rating
# 20            10  1440.0               Телефон  Віктор       5
# 21             0   280.0               Телефон   Ірина       4
# 33            15   952.0  Мобільний застосунок   Софія       5
# 37             0   280.0  Мобільний застосунок    Олег       5
# 43             0   320.0               Телефон  Віктор       4

# %% [markdown]
# **Завдання 55.** Виведіть усі замовлення жанру `Детектив`.

# %%
# Завдання 55:
df[df["genre"] == "Детектив"].head() # is not so lange
# Out:
#     order_id        date    city                 book_title     genre  \
# 4       5032  2024-01-27    Київ               Шерлок Холмс  Детектив
# 16      5102  2024-03-03    Київ               Шерлок Холмс  Детектив
# 26      5175  2024-04-26  Дніпро               Шерлок Холмс  Детектив
# 31      5297  2024-06-20   Львів  Кладовище домашніх тварин  Детектив
# 34      5158  2024-04-02   Львів  Кладовище домашніх тварин  Детектив
#
#     unit_price  quantity  discount_pct   total               channel manager  \
# 4          250         1            20   200.0                  Сайт    Олег
# 16         250         3             0   750.0                  Сайт    Олег
# 26         250         3             0   750.0               Телефон   Софія
# 31         270         4             0  1080.0  Мобільний застосунок    Олег
# 34         270         2            20   432.0                  Сайт   Софія
#
#     rating
# 4        3
# 16       5
# 26       4
# 31       4
# 34       5

# %% [markdown]
# **Завдання 56.** Виведіть усі замовлення жанру `Дитяча`.

# %%
# Завдання 56:
df[df["genre"] == "Дитяча"].head()
# Out:
#     order_id        date    city       book_title   genre  unit_price  \
# 5       5137  2024-03-06  Харків  Маленький принц  Дитяча         160
# 36      5016  2024-01-15  Дніпро  Маленький принц  Дитяча         160
# 39      5101  2024-03-11    Київ  Маленький принц  Дитяча         160
# 54      5144  2024-03-25   Львів  Маленький принц  Дитяча         160
# 61      5091  2024-02-01   Одеса  Маленький принц  Дитяча         160
#
#     quantity  discount_pct  total               channel manager  rating
# 5          2             0  320.0               Телефон    Олег       3
# 36         1             0  160.0                  Сайт   Ірина       4
# 39         1             0  160.0  Мобільний застосунок  Віктор       4
# 54         1             5  152.0               Телефон   Ірина       5
# 61         2             0  320.0                  Сайт  Віктор       4

# %% [markdown]
# **Завдання 57.** Виведіть замовлення, де сума (`total`) більша за 500.

# %%
# Завдання 57:
df[df["total"] > 500]
# Out:
#      order_id        date    city              book_title       genre  \
# 0        5275  2024-06-25  Харків                 Sapiens       Наука
# 8        5104  2024-03-13  Харків         Квантова фізика       Наука
# 11       5114  2024-03-21   Одеса         Квантова фізика       Наука
# 12       5215  2024-05-01  Харків             Сила звички      Бізнес
# 14       5295  2024-06-12    Київ             Війна і мир     Історія
# ..        ...         ...     ...                     ...         ...
# 393      5341  2024-07-17   Львів         Маленький принц      Дитяча
# 394      5191  2024-04-05   Львів             Війна і мир     Історія
# 395      5043  2024-01-22   Львів                    Дюна  Фантастика
# 396      5129  2024-03-21  Харків                 Sapiens       Наука
# 398      5336  2024-07-26   Львів  Гордість і упередження   Романтика
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 58.** Виведіть замовлення, де сума (`total`) більша за 1000.

# %%
# Завдання 58:
df[df["total"]>1000]
# Out:
#      order_id        date    city                 book_title       genre  \
# 11       5114  2024-03-21   Одеса            Квантова фізика       Наука
# 20       5165  2024-04-14  Харків                       Дюна  Фантастика
# 31       5297  2024-06-20   Львів  Кладовище домашніх тварин    Детектив
# 35       5055  2024-02-09   Одеса              Атомні звички      Бізнес
# 42       5130  2024-03-04  Харків     Гордість і упередження   Романтика
# 44       5317  2024-07-26  Харків              Атомні звички      Бізнес
# 55       5125  2024-03-26    Київ            Квантова фізика       Наука
# 56       5081  2024-02-01   Львів            Квантова фізика       Наука
# 57       5122  2024-03-04   Львів                Сила звички      Бізнес
# 58       5277  2024-06-18   Одеса              Атомні звички      Бізнес
# 63       5160  2024-04-28   Львів            Квантова фізика       Наука
# 84       5132  2024-03-23    Київ            Квантова фізика       Наука
# ...

# %% [markdown]
# **Завдання 59.** Виведіть замовлення, де сума (`total`) менша за 200.

# %%
# Завдання 59:
df[df["total"] < 200].head()
# Out:
#     order_id        date    city            book_title    genre  unit_price  \
# 9       5184  2024-04-24   Львів                Кобзар   Поезія         180
# 17      5342  2024-07-22  Дніпро  Тіні забутих предків  Історія         220
# 36      5016  2024-01-15  Дніпро       Маленький принц   Дитяча         160
# 39      5101  2024-03-11    Київ       Маленький принц   Дитяча         160
# 54      5144  2024-03-25   Львів       Маленький принц   Дитяча         160
#
#     quantity  discount_pct  total               channel manager  rating
# 9          1             0  180.0  Мобільний застосунок   Софія       4
# 17         1            15  187.0               Телефон   Ірина       5
# 36         1             0  160.0                  Сайт   Ірина       4
# 39         1             0  160.0  Мобільний застосунок  Віктор       4
# 54         1             5  152.0               Телефон   Ірина       5

# %% [markdown]
# **Завдання 60.** Виведіть замовлення, де кількість книг (`quantity`) дорівнює 5.

# %%
# Завдання 60:
df[df["quantity"] == 5]
# Out:
#      order_id        date    city                 book_title       genre  \
# 20       5165  2024-04-14  Харків                       Дюна  Фантастика
# 42       5130  2024-03-04  Харків     Гордість і упередження   Романтика
# 84       5132  2024-03-23    Київ            Квантова фізика       Наука
# 92       5400  2024-08-23   Одеса                       Дюна  Фантастика
# 114      5339  2024-07-02  Харків  Кладовище домашніх тварин    Детектив
# 118      5241  2024-05-16   Львів               Гаррі Поттер      Дитяча
# 143      5247  2024-05-15  Дніпро                       1984  Фантастика
# 191      5324  2024-07-08   Львів                Війна і мир     Історія
# 200      5183  2024-04-07   Львів                    Sapiens       Наука
# 234      5246  2024-05-17  Харків                    Sapiens       Наука
# 249      5365  2024-08-26    Київ            Квантова фізика       Наука
# 262      5041  2024-01-07   Львів            Маленький принц      Дитяча
# ...

# %% [markdown]
# **Завдання 61.** Виведіть замовлення, де кількість книг більша за 3.

# %%
# Завдання 61:
df[df["quantity"] > 3]
# Out:
#      order_id        date    city                 book_title       genre  \
# 20       5165  2024-04-14  Харків                       Дюна  Фантастика
# 22       5025  2024-01-08   Одеса       Тіні забутих предків     Історія
# 31       5297  2024-06-20   Львів  Кладовище домашніх тварин    Детектив
# 33       5288  2024-06-10    Київ                       1984  Фантастика
# 35       5055  2024-02-09   Одеса              Атомні звички      Бізнес
# 42       5130  2024-03-04  Харків     Гордість і упередження   Романтика
# 44       5317  2024-07-26  Харків              Атомні звички      Бізнес
# 56       5081  2024-02-01   Львів            Квантова фізика       Наука
# 57       5122  2024-03-04   Львів                Сила звички      Бізнес
# 58       5277  2024-06-18   Одеса              Атомні звички      Бізнес
# 63       5160  2024-04-28   Львів            Квантова фізика       Наука
# 84       5132  2024-03-23    Київ            Квантова фізика       Наука
# ...

# %% [markdown]
# **Завдання 62.** Виведіть замовлення з оцінкою (`rating`) 5.

# %%
# Завдання 62:
df[df["rating"] == 5]
# Out:
#      order_id        date    city                 book_title      genre  \
# 0        5275  2024-06-25  Харків                    Sapiens      Наука
# 1        5386  2024-08-09   Одеса     Гордість і упередження  Романтика
# 2        5100  2024-02-21  Харків     Гордість і упередження  Романтика
# 14       5295  2024-06-12    Київ                Війна і мир    Історія
# 16       5102  2024-03-03    Київ               Шерлок Холмс   Детектив
# ..        ...         ...     ...                        ...        ...
# 389      5203  2024-05-21  Харків  Кладовище домашніх тварин   Детектив
# 393      5341  2024-07-17   Львів            Маленький принц     Дитяча
# 396      5129  2024-03-21  Харків                    Sapiens      Наука
# 397      5185  2024-04-22    Київ                Війна і мир    Історія
# 398      5336  2024-07-26   Львів     Гордість і упередження  Романтика
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 63.** Виведіть замовлення з оцінкою менше 4.

# %%
# Завдання 63:
df[df["rating"] >= 4]
# Out:
#      order_id        date    city              book_title      genre  \
# 0        5275  2024-06-25  Харків                 Sapiens      Наука
# 1        5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2        5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 6        5022  2024-01-24    Київ            Лісова пісня     Поезія
# 7        5139  2024-03-22    Київ            Лісова пісня     Поезія
# ..        ...         ...     ...                     ...        ...
# 393      5341  2024-07-17   Львів         Маленький принц     Дитяча
# 394      5191  2024-04-05   Львів             Війна і мир    Історія
# 396      5129  2024-03-21  Харків                 Sapiens      Наука
# 397      5185  2024-04-22    Київ             Війна і мир    Історія
# 398      5336  2024-07-26   Львів  Гордість і упередження  Романтика
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 64.** Виведіть замовлення книги `Дюна`.
#
# > 💡 df[df["book_title"] == "Дюна"].

# %%
# Завдання 64:
df[df["book_title"] == "Дюна"]
# Out:
#      order_id        date    city book_title       genre  unit_price  \
# 20       5165  2024-04-14  Харків       Дюна  Фантастика         320
# 43       5346  2024-07-03  Дніпро       Дюна  Фантастика         320
# 50       5164  2024-04-22  Харків       Дюна  Фантастика         320
# 59       5294  2024-06-25   Одеса       Дюна  Фантастика         320
# 70       5153  2024-04-04  Дніпро       Дюна  Фантастика         320
# 92       5400  2024-08-23   Одеса       Дюна  Фантастика         320
# 136      5334  2024-07-20  Харків       Дюна  Фантастика         320
# 139      5353  2024-08-03  Дніпро       Дюна  Фантастика         320
# 147      5385  2024-08-06  Дніпро       Дюна  Фантастика         320
# 156      5221  2024-05-23  Харків       Дюна  Фантастика         320
# 238      5274  2024-06-07   Одеса       Дюна  Фантастика         320
# 243      5030  2024-01-28   Львів       Дюна  Фантастика         320
# 245      5237  2024-05-21  Харків       Дюна  Фантастика         320
# ...

# %% [markdown]
# **Завдання 65.** Виведіть замовлення книги `1984`.

# %%
# Завдання 65:
df[df["book_title"] == "1984"]
# Out:
#      order_id        date    city book_title       genre  unit_price  \
# 21       5194  2024-04-21   Одеса       1984  Фантастика         280
# 33       5288  2024-06-10    Київ       1984  Фантастика         280
# 37       5382  2024-08-02    Київ       1984  Фантастика         280
# 75       5344  2024-07-28  Дніпро       1984  Фантастика         280
# 76       5283  2024-06-08  Дніпро       1984  Фантастика         280
# 78       5390  2024-08-26   Одеса       1984  Фантастика         280
# 123      5234  2024-05-02   Одеса       1984  Фантастика         280
# 124      5343  2024-07-07  Харків       1984  Фантастика         280
# 131      5051  2024-02-14   Львів       1984  Фантастика         280
# 143      5247  2024-05-15  Дніпро       1984  Фантастика         280
# 148      5018  2024-01-24  Дніпро       1984  Фантастика         280
# 161      5082  2024-02-04   Львів       1984  Фантастика         280
# 214      5192  2024-04-21  Харків       1984  Фантастика         280
# ...

# %% [markdown]
# **Завдання 66.** Виведіть замовлення, оформлені через канал `Сайт`.

# %%
# Завдання 66:
df[df["channel"] == "Сайт"]
# Out:
#      order_id        date    city                 book_title      genre  \
# 2        5100  2024-02-21  Харків     Гордість і упередження  Романтика
# 4        5032  2024-01-27    Київ               Шерлок Холмс   Детектив
# 11       5114  2024-03-21   Одеса            Квантова фізика      Наука
# 16       5102  2024-03-03    Київ               Шерлок Холмс   Детектив
# 22       5025  2024-01-08   Одеса       Тіні забутих предків    Історія
# ..        ...         ...     ...                        ...        ...
# 389      5203  2024-05-21  Харків  Кладовище домашніх тварин   Детектив
# 390      5027  2024-01-17  Харків               Лісова пісня     Поезія
# 393      5341  2024-07-17   Львів            Маленький принц     Дитяча
# 396      5129  2024-03-21  Харків                    Sapiens      Наука
# 398      5336  2024-07-26   Львів     Гордість і упередження  Романтика
#
#      unit_price  quantity  discount_pct   total channel manager  rating
# ...

# %% [markdown]
# **Завдання 67.** Виведіть замовлення, оформлені через канал `Телефон`.

# %%
# Завдання 67:
df[df["channel"] == "Телефон"]
# Out:
#      order_id        date    city                 book_title      genre  \
# 0        5275  2024-06-25  Харків                    Sapiens      Наука
# 1        5386  2024-08-09   Одеса     Гордість і упередження  Романтика
# 5        5137  2024-03-06  Харків            Маленький принц     Дитяча
# 6        5022  2024-01-24    Київ               Лісова пісня     Поезія
# 10       5208  2024-05-13   Львів               Лісова пісня     Поезія
# ..        ...         ...     ...                        ...        ...
# 384      5120  2024-03-23    Київ     Гордість і упередження  Романтика
# 385      5359  2024-08-11  Харків       Тіні забутих предків    Історія
# 386      5372  2024-08-24   Львів  Кладовище домашніх тварин   Детектив
# 388      5321  2024-07-09  Дніпро     Гордість і упередження  Романтика
# 391      5085  2024-02-08   Одеса               Шерлок Холмс   Детектив
#
#      unit_price  quantity  discount_pct  total  channel manager  rating
# ...

# %% [markdown]
# **Завдання 68.** Виведіть замовлення менеджера `Ірина`.

# %%
# Завдання 68:
df[df["manager"] == "Ірина"]
# Out:
#      order_id        date    city              book_title       genre  \
# 0        5275  2024-06-25  Харків                 Sapiens       Наука
# 1        5386  2024-08-09   Одеса  Гордість і упередження   Романтика
# 2        5100  2024-02-21  Харків  Гордість і упередження   Романтика
# 13       5320  2024-07-21  Харків                 Sapiens       Наука
# 14       5295  2024-06-12    Київ             Війна і мир     Історія
# ..        ...         ...     ...                     ...         ...
# 388      5321  2024-07-09  Дніпро  Гордість і упередження   Романтика
# 395      5043  2024-01-22   Львів                    Дюна  Фантастика
# 397      5185  2024-04-22    Київ             Війна і мир     Історія
# 398      5336  2024-07-26   Львів  Гордість і упередження   Романтика
# 399      5048  2024-01-14   Одеса             Сила звички      Бізнес
#
#      unit_price  quantity  discount_pct  total               channel manager  \
# ...

# %% [markdown]
# **Завдання 69.** Виведіть замовлення, де була застосована знижка (`discount_pct` більше 0).

# %%
# Завдання 69:
df[df["discount_pct"] != 0]
# Out:
#      order_id        date    city                 book_title      genre  \
# 2        5100  2024-02-21  Харків     Гордість і упередження  Романтика
# 4        5032  2024-01-27    Київ               Шерлок Холмс   Детектив
# 7        5139  2024-03-22    Київ               Лісова пісня     Поезія
# 8        5104  2024-03-13  Харків            Квантова фізика      Наука
# 17       5342  2024-07-22  Дніпро       Тіні забутих предків    Історія
# ..        ...         ...     ...                        ...        ...
# 385      5359  2024-08-11  Харків       Тіні забутих предків    Історія
# 386      5372  2024-08-24   Львів  Кладовище домашніх тварин   Детектив
# 391      5085  2024-02-08   Одеса               Шерлок Холмс   Детектив
# 393      5341  2024-07-17   Львів            Маленький принц     Дитяча
# 396      5129  2024-03-21  Харків                    Sapiens      Наука
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 70.** Виведіть замовлення, де ціна книги (`unit_price`) дорівнює або більша за 400.

# %%
# Завдання 70:
df[df["unit_price"] >= 400]
# Out:
#      order_id        date    city       book_title  genre  unit_price  \
# 0        5275  2024-06-25  Харків          Sapiens  Наука         410
# 3        5352  2024-08-18  Дніпро          Sapiens  Наука         410
# 8        5104  2024-03-13  Харків  Квантова фізика  Наука         450
# 11       5114  2024-03-21   Одеса  Квантова фізика  Наука         450
# 13       5320  2024-07-21  Харків          Sapiens  Наука         410
# ..        ...         ...     ...              ...    ...         ...
# 348      5069  2024-02-06  Харків          Sapiens  Наука         410
# 353      5161  2024-04-01   Одеса  Квантова фізика  Наука         450
# 363      5217  2024-05-27   Львів  Квантова фізика  Наука         450
# 373      5304  2024-07-07    Київ          Sapiens  Наука         410
# 396      5129  2024-03-21  Харків          Sapiens  Наука         410
#
#      quantity  discount_pct   total               channel manager  rating
# ...

# %% [markdown]
# ## Розділ 5. Фільтрація + підрахунок (завдання 71-80)
#
# Поєднуємо фільтр з `len()` або агрегатами, щоб одразу отримати число.

# %% [markdown]
# **Завдання 71.** Скільки замовлень з міста Київ?
#
# > 💡 Оберніть фільтр у len(): len(df[df["city"] == "Київ"]).

# %%
len(df[df["city"] == "Київ"])
# Out:
# 68

# %% [markdown]
# **Завдання 72.** Скільки замовлень жанру `Наука`?

# %%
# Завдання 72:
len(df[df["genre"] == "Наука"])
# Out:
# 61

# %% [markdown]
# **Завдання 73.** Скільки замовлень із сумою більше 800?

# %%
# Завдання 73:
len(df[df["total"] > 800])
# Out:
# 95

# %% [markdown]
# **Завдання 74.** Яка загальна виручка (`total`) з міста Львів?
#
# > 💡 Відфільтруйте Львів, потім візьміть ["total"].sum().

# %%
# Завдання 74:

df.groupby("city")["total"].sum()["Львів"]
# Out:
# np.float64(50604.5)

# %% [markdown]
# **Завдання 75.** Яка загальна виручка з жанру `Бізнес`?

# %%
# Завдання 75:
df.groupby("genre")["total"].sum()["Бізнес"]
# Out:
# np.float64(34612.0)

# %% [markdown]
# **Завдання 76.** Яка середня сума замовлення в місті Одеса?

# %%
# Завдання 76:
df.groupby("city")["total"].mean()["Одеса"]
# Out:
# np.float64(586.4451219512196)

# %% [markdown]
# **Завдання 77.** Скільки замовлень з оцінкою 5?

# %%
# Завдання 77:
df.groupby("rating")["order_id"].count()[5]
# Out:
# np.int64(164)

# %% [markdown]
# **Завдання 78.** Скільки книг (`quantity`) було продано в місті Харків?
#
# > 💡 Фільтр + ["quantity"].sum().

# %%
# Завдання 78:
df.groupby("city")["quantity"].count()["Харків"]
# Out:
# np.int64(98)

# %% [markdown]
# **Завдання 79.** Яка середня оцінка замовлень через канал `Мобільний застосунок`?

# %%
# Завдання 79:
df.groupby("channel")["rating"].mean()["Мобільний застосунок"]
# Out:
# np.float64(4.207407407407407)

# %% [markdown]
# **Завдання 80.** Скільки замовлень оформила менеджер `Софія`?

# %%
# Завдання 80:
df.groupby("manager")["order_id"].sum()["Софія"]
# Out:
# np.int64(461511)

# %% [markdown]
# ## Розділ 6. Фільтрація — кілька умов (завдання 81-95)
#
# Поєднуємо умови через `&` (І) та `|` (АБО). Кожну умову беремо в дужки!
# Наприклад: `df[(df["city"] == "Київ") & (df["total"] > 500)]`.

# %% [markdown]
# **Завдання 81.** Виведіть замовлення з Києва, де сума більша за 500.
#
# > 💡 Дві умови через &, кожна в дужках.

# %%
# Завдання 81:
df[(df["city"] == "Київ") & (df["total"] >500)].head(5)
# Out:
#     order_id        date  city       book_title       genre  unit_price  \
# 14      5295  2024-06-12  Київ      Війна і мир     Історія         380
# 16      5102  2024-03-03  Київ     Шерлок Холмс    Детектив         250
# 24      5253  2024-06-27  Київ    Атомні звички      Бізнес         290
# 33      5288  2024-06-10  Київ             1984  Фантастика         280
# 55      5125  2024-03-26  Київ  Квантова фізика       Наука         450
#
#     quantity  discount_pct   total               channel manager  rating
# 14         2             0   760.0               Телефон   Ірина       5
# 16         3             0   750.0                  Сайт    Олег       5
# 24         3             0   870.0                  Сайт   Софія       5
# 33         4            15   952.0  Мобільний застосунок   Софія       5
# 55         3             0  1350.0  Мобільний застосунок  Наталя       4

# %% [markdown]
# **Завдання 82.** Виведіть замовлення жанру `Фантастика` із сумою більше 600.

# %%
# Завдання 82:
df[(df["genre"] == "Фантастика") & (df["total"] >600)].head(5)
# Out:
#      order_id        date    city book_title       genre  unit_price  \
# 20       5165  2024-04-14  Харків       Дюна  Фантастика         320
# 33       5288  2024-06-10    Київ       1984  Фантастика         280
# 78       5390  2024-08-26   Одеса       1984  Фантастика         280
# 92       5400  2024-08-23   Одеса       Дюна  Фантастика         320
# 124      5343  2024-07-07  Харків       1984  Фантастика         280
#
#      quantity  discount_pct   total               channel manager  rating
# 20          5            10  1440.0               Телефон  Віктор       5
# 33          4            15   952.0  Мобільний застосунок   Софія       5
# 78          3             5   798.0               Телефон  Наталя       3
# 92          5             0  1600.0                  Сайт  Наталя       5
# 124         4             0  1120.0                  Сайт  Наталя       5

# %% [markdown]
# **Завдання 83.** Виведіть замовлення з Львова з оцінкою 5.

# %%
# Завдання 83:
df[(df["city"] == "Львів") & (df["rating"] == 5)].head(5)
# Out:
#     order_id        date   city                 book_title     genre  \
# 34      5158  2024-04-02  Львів  Кладовище домашніх тварин  Детектив
# 46      5373  2024-08-08  Львів              Атомні звички    Бізнес
# 54      5144  2024-03-25  Львів            Маленький принц    Дитяча
# 56      5081  2024-02-01  Львів            Квантова фізика     Наука
# 57      5122  2024-03-04  Львів                Сила звички    Бізнес
#
#     unit_price  quantity  discount_pct   total               channel manager  \
# 34         270         2            20   432.0                  Сайт   Софія
# 46         290         2            15   493.0                  Сайт  Віктор
# 54         160         1             5   152.0               Телефон   Ірина
# 56         450         4             0  1800.0                  Сайт   Софія
# 57         260         4             0  1040.0  Мобільний застосунок  Наталя
#
#     rating
# 34       5
# 46       5
# 54       5
# 56       5
# 57       5

# %% [markdown]
# **Завдання 84.** Виведіть замовлення, де жанр `Детектив` АБО `Фантастика`.
#
# > 💡 Використайте | (АБО).

# %%
# Завдання 84:
df[(df["genre"] == "Детектив") | (df["genre"] == "Фантастика")].head(5)
# Out:
#     order_id        date    city    book_title       genre  unit_price  \
# 4       5032  2024-01-27    Київ  Шерлок Холмс    Детектив         250
# 16      5102  2024-03-03    Київ  Шерлок Холмс    Детектив         250
# 20      5165  2024-04-14  Харків          Дюна  Фантастика         320
# 21      5194  2024-04-21   Одеса          1984  Фантастика         280
# 26      5175  2024-04-26  Дніпро  Шерлок Холмс    Детектив         250
#
#     quantity  discount_pct   total  channel manager  rating
# 4          1            20   200.0     Сайт    Олег       3
# 16         3             0   750.0     Сайт    Олег       5
# 20         5            10  1440.0  Телефон  Віктор       5
# 21         1             0   280.0  Телефон   Ірина       4
# 26         3             0   750.0  Телефон   Софія       4

# %% [markdown]
# **Завдання 85.** Виведіть замовлення з міст Київ АБО Одеса.

# %%
# Завдання 85:
df[(df["city"] == "Київ") | (df["city"] == "Одеса")].head(5)
# Out:
#     order_id        date   city              book_title      genre  \
# 1       5386  2024-08-09  Одеса  Гордість і упередження  Романтика
# 4       5032  2024-01-27   Київ            Шерлок Холмс   Детектив
# 6       5022  2024-01-24   Київ            Лісова пісня     Поезія
# 7       5139  2024-03-22   Київ            Лісова пісня     Поезія
# 11      5114  2024-03-21  Одеса         Квантова фізика      Наука
#
#     unit_price  quantity  discount_pct   total               channel manager  \
# 1          240         2             0   480.0               Телефон   Ірина
# 4          250         1            20   200.0                  Сайт    Олег
# 6          150         2             0   300.0               Телефон    Олег
# 7          150         3            10   405.0  Мобільний застосунок  Наталя
# 11         450         3             0  1350.0                  Сайт   Софія
#
#     rating
# 1        5
# 4        3
# 6        4
# 7        4
# 11       4

# %% [markdown]
# **Завдання 86.** Виведіть замовлення, де кількість книг більша за 2 І застосована знижка (>0).

# %%
# Завдання 86:
df[(df["quantity"] > 2) | (df["discount_pct"] >0)].head(5)
# Out:
#     order_id        date    city              book_title      genre  \
# 2       5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 4       5032  2024-01-27    Київ            Шерлок Холмс   Детектив
# 7       5139  2024-03-22    Київ            Лісова пісня     Поезія
# 8       5104  2024-03-13  Харків         Квантова фізика      Наука
# 10      5208  2024-05-13   Львів            Лісова пісня     Поезія
#
#     unit_price  quantity  discount_pct  total               channel manager  \
# 2          240         1            15  204.0                  Сайт   Ірина
# 4          250         1            20  200.0                  Сайт    Олег
# 7          150         3            10  405.0  Мобільний застосунок  Наталя
# 8          450         2             5  855.0  Мобільний застосунок   Софія
# 10         150         3             0  450.0               Телефон   Софія
#
#     rating
# 2        5
# 4        3
# 7        4
# 8        4
# 10       4

# %% [markdown]
# **Завдання 87.** Виведіть замовлення з Харкова через канал `Сайт`.

# %%
# Завдання 87:
df[(df["channel"] == "Сайт") | (df["city"] == "Харків")].head(5)
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 4      5032  2024-01-27    Київ            Шерлок Холмс   Детектив
# 5      5137  2024-03-06  Харків         Маленький принц     Дитяча
# 8      5104  2024-03-13  Харків         Квантова фізика      Наука
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 4         250         1            20  200.0                  Сайт    Олег
# 5         160         2             0  320.0               Телефон    Олег
# 8         450         2             5  855.0  Мобільний застосунок   Софія
#
#    rating
# 0       5
# 2       5
# 4       3
# 5       3
# 8       4

# %% [markdown]
# **Завдання 88.** Виведіть замовлення менеджера `Олег` із сумою більше 700.

# %%
# Завдання 88:
df[(df["manager"] == "Олег") | (df["total"] >700)].head(5)
# Out:
#    order_id        date    city       book_title     genre  unit_price  \
# 0      5275  2024-06-25  Харків          Sapiens     Наука         410
# 4      5032  2024-01-27    Київ     Шерлок Холмс  Детектив         250
# 5      5137  2024-03-06  Харків  Маленький принц    Дитяча         160
# 6      5022  2024-01-24    Київ     Лісова пісня    Поезія         150
# 8      5104  2024-03-13  Харків  Квантова фізика     Наука         450
#
#    quantity  discount_pct  total               channel manager  rating
# 0         2             0  820.0               Телефон   Ірина       5
# 4         1            20  200.0                  Сайт    Олег       3
# 5         2             0  320.0               Телефон    Олег       3
# 6         2             0  300.0               Телефон    Олег       4
# 8         2             5  855.0  Мобільний застосунок   Софія       4

# %% [markdown]
# **Завдання 89.** Виведіть замовлення книги `Гаррі Поттер` з оцінкою 5.

# %%
# Завдання 89:
df[(df["book_title"] == "Гаррі Поттер$0") | (df["rating"] == 5)].head(5)
# Out:
#     order_id        date    city              book_title      genre  \
# 0       5275  2024-06-25  Харків                 Sapiens      Наука
# 1       5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2       5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 14      5295  2024-06-12    Київ             Війна і мир    Історія
# 16      5102  2024-03-03    Київ            Шерлок Холмс   Детектив
#
#     unit_price  quantity  discount_pct  total  channel manager  rating
# 0          410         2             0  820.0  Телефон   Ірина       5
# 1          240         2             0  480.0  Телефон   Ірина       5
# 2          240         1            15  204.0     Сайт   Ірина       5
# 14         380         2             0  760.0  Телефон   Ірина       5
# 16         250         3             0  750.0     Сайт    Олег       5

# %% [markdown]
# **Завдання 90.** Виведіть замовлення, де ціна (`unit_price`) між 200 і 300 (більше або дорівнює 200 І менше або дорівнює 300).

# %%
# Завдання 90:
df[(df["unit_price"] >=200) | (df["unit_price"] <=300 )]
# Out:
#      order_id        date    city              book_title       genre  \
# 0        5275  2024-06-25  Харків                 Sapiens       Наука
# 1        5386  2024-08-09   Одеса  Гордість і упередження   Романтика
# 2        5100  2024-02-21  Харків  Гордість і упередження   Романтика
# 3        5352  2024-08-18  Дніпро                 Sapiens       Наука
# 4        5032  2024-01-27    Київ            Шерлок Холмс    Детектив
# ..        ...         ...     ...                     ...         ...
# 395      5043  2024-01-22   Львів                    Дюна  Фантастика
# 396      5129  2024-03-21  Харків                 Sapiens       Наука
# 397      5185  2024-04-22    Київ             Війна і мир     Історія
# 398      5336  2024-07-26   Львів  Гордість і упередження   Романтика
# 399      5048  2024-01-14   Одеса             Сила звички      Бізнес
#
#      unit_price  quantity  discount_pct   total               channel manager  \
# ...

# %% [markdown]
# **Завдання 91.** Виведіть замовлення з оцінкою 4 АБО 5.

# %%
# Завдання 91:
df[(df["rating"] == 4) | (df["rating"] == 5)].head(5)
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 6      5022  2024-01-24    Київ            Лісова пісня     Поезія
# 7      5139  2024-03-22    Київ            Лісова пісня     Поезія
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 6         150         2             0  300.0               Телефон    Олег
# 7         150         3            10  405.0  Мобільний застосунок  Наталя
#
#    rating
# 0       5
# 1       5
# 2       5
# 6       4
# 7       4

# %% [markdown]
# **Завдання 92.** Виведіть замовлення жанру `Наука` з міста Київ.

# %%
# Завдання 92:
df[(df["genre"] == "Наука") & (df["city"] == "Київ")].head(5)
# Out:
#      order_id        date  city       book_title  genre  unit_price  quantity  \
# 48       5267  2024-06-13  Київ  Квантова фізика  Наука         450         1
# 55       5125  2024-03-26  Київ  Квантова фізика  Наука         450         3
# 84       5132  2024-03-23  Київ  Квантова фізика  Наука         450         5
# 109      5376  2024-08-11  Київ  Квантова фізика  Наука         450         3
# 221      5258  2024-06-11  Київ  Квантова фізика  Наука         450         1
#
#      discount_pct   total               channel manager  rating
# 48              0   450.0                  Сайт    Олег       4
# 55              0  1350.0  Мобільний застосунок  Наталя       4
# 84              0  2250.0  Мобільний застосунок   Софія       4
# 109             0  1350.0  Мобільний застосунок  Віктор       4
# 221             0   450.0  Мобільний застосунок  Віктор       4

# %% [markdown]
# **Завдання 93.** Виведіть замовлення зі знижкою 10% або 15%.
#
# > 💡 Дві умови через |.

# %%
# Завдання 93:
df[(df["discount_pct"] == 10) | (df["discount_pct"] == 15)].head(5)
# Out:
#     order_id        date    city              book_title       genre  \
# 2       5100  2024-02-21  Харків  Гордість і упередження   Романтика
# 7       5139  2024-03-22    Київ            Лісова пісня      Поезія
# 17      5342  2024-07-22  Дніпро    Тіні забутих предків     Історія
# 20      5165  2024-04-14  Харків                    Дюна  Фантастика
# 27      5307  2024-07-13  Дніпро    Тіні забутих предків     Історія
#
#     unit_price  quantity  discount_pct   total               channel manager  \
# 2          240         1            15   204.0                  Сайт   Ірина
# 7          150         3            10   405.0  Мобільний застосунок  Наталя
# 17         220         1            15   187.0               Телефон   Ірина
# 20         320         5            10  1440.0               Телефон  Віктор
# 27         220         3            10   594.0                  Сайт  Наталя
#
#     rating
# 2        5
# 7        4
# 17       5
# 20       5
# 27       3

# %% [markdown]
# **Завдання 94.** Виведіть замовлення через канал `Телефон` із сумою менше 300.

# %%
# Завдання 94:
df[(df["channel"] == "Телефон") & (df["total"]< 300)].head(5)
# Out:
#     order_id        date    city                 book_title       genre  \
# 17      5342  2024-07-22  Дніпро       Тіні забутих предків     Історія
# 21      5194  2024-04-21   Одеса                       1984  Фантастика
# 32      5303  2024-07-18   Одеса     Гордість і упередження   Романтика
# 40      5252  2024-06-05  Дніпро  Кладовище домашніх тварин    Детектив
# 54      5144  2024-03-25   Львів            Маленький принц      Дитяча
#
#     unit_price  quantity  discount_pct  total  channel manager  rating
# 17         220         1            15  187.0  Телефон   Ірина       5
# 21         280         1             0  280.0  Телефон   Ірина       4
# 32         240         1             0  240.0  Телефон   Ірина       4
# 40         270         1            15  229.5  Телефон   Софія       4
# 54         160         1             5  152.0  Телефон   Ірина       5

# %% [markdown]
# **Завдання 95.** Скільки замовлень з Києва із сумою більше 500?
#
# > 💡 Поєднайте фільтр з кількох умов і len().

# %%
# Завдання 95:
df[(df["total"] > 500) & (df["city"] == "Київ")].head(5)
# Out:
#     order_id        date  city       book_title       genre  unit_price  \
# 14      5295  2024-06-12  Київ      Війна і мир     Історія         380
# 16      5102  2024-03-03  Київ     Шерлок Холмс    Детектив         250
# 24      5253  2024-06-27  Київ    Атомні звички      Бізнес         290
# 33      5288  2024-06-10  Київ             1984  Фантастика         280
# 55      5125  2024-03-26  Київ  Квантова фізика       Наука         450
#
#     quantity  discount_pct   total               channel manager  rating
# 14         2             0   760.0               Телефон   Ірина       5
# 16         3             0   750.0                  Сайт    Олег       5
# 24         3             0   870.0                  Сайт   Софія       5
# 33         4            15   952.0  Мобільний застосунок   Софія       5
# 55         3             0  1350.0  Мобільний застосунок  Наталя       4

# %% [markdown]
# ## Розділ 7. Створення нових стовпців (завдання 96-105)
#
# Новий стовпець: `df["нова_назва"] = вираз`. Операції застосовуються до всього стовпця одразу.

# %% [markdown]
# **Завдання 96.** Створіть стовпець `full_price`, що дорівнює `unit_price` × `quantity` (ціна без знижки).

# %%
# Завдання 96:
df["full_price"] = df["unit_price"] * df["quantity"]
print(df["full_price"])
# Out:
# 0       820
# 1       480
# 2       240
# 3       410
# 4       250
#        ...
# 395     640
# 396    2050
# 397     380
# 398     720
# 399     260
# Name: full_price, Length: 400, dtype: int64

# %% [markdown]
# **Завдання 97.** Створіть стовпець `discount_amount` = `full_price` − `total` (скільки зекономлено на знижці).
#
# > 💡 Спочатку виконайте попереднє завдання, щоб був стовпець full_price.

# %%
# Завдання 97:
df["full_price"] = df["unit_price"] * df["quantity"]
df["discount_amount"] = df["full_price"] - df["total"]
print(df["discount_amount"])
# Out:
# 0        0.0
# 1        0.0
# 2       36.0
# 3        0.0
# 4       50.0
#        ...
# 395      0.0
# 396    102.5
# 397      0.0
# 398      0.0
# 399      0.0
# Name: discount_amount, Length: 400, dtype: float64

# %% [markdown]
# **Завдання 98.** Створіть стовпець `price_with_tax`, що дорівнює `total`, збільшеному на 5% (помножте на 1.05).

# %%
# Завдання 98:
df["price_with_tax"] = df["total"] * 1.05
print(df["price_with_tax"].round(2).head(10))
# Out:
# 0    861.00
# 1    504.00
# 2    214.20
# 3    430.50
# 4    210.00
# 5    336.00
# 6    315.00
# 7    425.25
# 8    897.75
# 9    189.00
# Name: price_with_tax, dtype: float64

# %% [markdown]
# **Завдання 99.** Створіть стовпець `is_big`, який дорівнює `True`, якщо `total` більше 700.
#
# > 💡 df["is_big"] = df["total"] > 700.

# %%
# Завдання 99:
df["is_big"] = df["total"] > 700
print(df["is_big"])
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 395    False
# 396     True
# 397    False
# 398     True
# 399    False
# Name: is_big, Length: 400, dtype: bool

# %% [markdown]
# **Завдання 100.** Створіть стовпець `is_discounted`, який дорівнює `True`, якщо `discount_pct` більше 0.

# %%
# Завдання 100:
df["is_discauntet"] = df["discount_pct"] > 0
print(df["is_discauntet"])
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 395    False
# 396     True
# 397    False
# 398    False
# 399    False
# Name: is_discauntet, Length: 400, dtype: bool

# %% [markdown]
# **Завдання 101.** Створіть стовпець `total_uah_rounded` — суму замовлення, округлену до цілого.
#
# > 💡 Використайте .round() на стовпці.

# %%
# Завдання 101:
df["total_uah_rounded"] = df["total"].round(2).head(5)
print(df.head(5))
# Out:
#    order_id        date    city              book_title      genre  \
# 0      5275  2024-06-25  Харків                 Sapiens      Наука
# 1      5386  2024-08-09   Одеса  Гордість і упередження  Романтика
# 2      5100  2024-02-21  Харків  Гордість і упередження  Романтика
# 3      5352  2024-08-18  Дніпро                 Sapiens      Наука
# 4      5032  2024-01-27    Київ            Шерлок Холмс   Детектив
#
#    unit_price  quantity  discount_pct  total               channel manager  \
# 0         410         2             0  820.0               Телефон   Ірина
# 1         240         2             0  480.0               Телефон   Ірина
# 2         240         1            15  204.0                  Сайт   Ірина
# 3         410         1             0  410.0  Мобільний застосунок  Віктор
# 4         250         1            20  200.0                  Сайт    Олег
#
#    rating  full_pice  full_price  discount_amount  price_with_tax  is_big  \
# ...

# %% [markdown]
# **Завдання 102.** Створіть стовпець `books_per_order`, що дублює `quantity` (просто скопіюйте стовпець у новий).

# %%
# Завдання 102:
df["books_per_order"] = df["quantity"]
print(df["books_per_order"])
# Out:
# 0      2
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 395    2
# 396    5
# 397    1
# 398    3
# 399    1
# Name: books_per_order, Length: 400, dtype: int64

# %% [markdown]
# **Завдання 103.** Створіть стовпець `high_rating`, який дорівнює `True`, якщо оцінка дорівнює 5.

# %%
# Завдання 103:
df["high_rating"] = df["rating"] == 5
print(df["high_rating"].head())
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: high_rating, dtype: bool

# %% [markdown]
# **Завдання 104.** Створіть стовпець `revenue_per_book` = `total` ÷ `quantity` (середня ціна за книгу в замовленні).

# %%
# Завдання 104:
df["revenue_per_book$0"] = df["total"] / df["quantity"]

# %% [markdown]
# **Завдання 105.** Створіть стовпець `city_upper`, де назва міста написана великими літерами.
#
# > 💡 Для тексту: df["city"].str.upper().

# %%
# Завдання 105:
df["city_upper"] = df["city"].str.upper()

# %% [markdown]
# ## Розділ 8. Сортування (завдання 106-112)
#
# `df.sort_values("стовпець")` — за зростанням, `ascending=False` — за спаданням.

# %% [markdown]
# **Завдання 106.** Відсортуйте таблицю за сумою (`total`) від найбільшої до найменшої. Виведіть перші 5.
#
# > 💡 sort_values з ascending=False.

# %%
# Завдання 106:
df.sort_values(["total"], ascending=False ).head(5)
# Out:
#      order_id        date    city       book_title  genre  unit_price  \
# 249      5365  2024-08-26    Київ  Квантова фізика  Наука         450
# 84       5132  2024-03-23    Київ  Квантова фізика  Наука         450
# 200      5183  2024-04-07   Львів          Sapiens  Наука         410
# 234      5246  2024-05-17  Харків          Sapiens  Наука         410
# 396      5129  2024-03-21  Харків          Sapiens  Наука         410
#
#      quantity  discount_pct   total               channel  ... full_price  \
# 249         5             0  2250.0                  Сайт  ...       2250
# 84          5             0  2250.0  Мобільний застосунок  ...       2250
# 200         5             0  2050.0                  Сайт  ...       2050
# 234         5             0  2050.0               Телефон  ...       2050
# 396         5             5  1947.5                  Сайт  ...       2050
#
#      discount_amount  price_with_tax  is_big  is_discauntet  \
# ...

# %% [markdown]
# **Завдання 107.** Відсортуйте таблицю за сумою (`total`) від найменшої до найбільшої. Виведіть перші 5.

# %%
# Завдання 107:
df.sort_values(["total"], ascending=True ).head(5)
# Out:
#      order_id        date    city       book_title   genre  unit_price  \
# 342      5289  2024-06-10  Дніпро  Маленький принц  Дитяча         160
# 133      5140  2024-03-23   Одеса  Маленький принц  Дитяча         160
# 315      5128  2024-03-14  Харків  Маленький принц  Дитяча         160
# 379      5049  2024-01-22  Дніпро     Лісова пісня  Поезія         150
# 308      5155  2024-04-16   Одеса     Лісова пісня  Поезія         150
#
#      quantity  discount_pct  total               channel  ... full_price  \
# 342         1            20  128.0               Телефон  ...        160
# 133         1            15  136.0                  Сайт  ...        160
# 315         1            10  144.0               Телефон  ...        160
# 379         1             0  150.0  Мобільний застосунок  ...        150
# 308         1             0  150.0                  Сайт  ...        150
#
#      discount_amount  price_with_tax  is_big  is_discauntet  \
# ...

# %% [markdown]
# **Завдання 108.** Відсортуйте таблицю за ціною книги (`unit_price`) за спаданням. Виведіть перші 10.

# %%
# Завдання 108:
df.sort_values(["unit_price"], ascending=False ).head(10)
# Out:
#      order_id        date    city       book_title  genre  unit_price  \
# 29       5351  2024-08-06  Дніпро  Квантова фізика  Наука         450
# 363      5217  2024-05-27   Львів  Квантова фізика  Наука         450
# 25       5193  2024-04-19  Дніпро  Квантова фізика  Наука         450
# 346      5347  2024-07-26  Харків  Квантова фізика  Наука         450
# 353      5161  2024-04-01   Одеса  Квантова фізика  Наука         450
# 306      5387  2024-08-14   Львів  Квантова фізика  Наука         450
# 327      5052  2024-02-02   Львів  Квантова фізика  Наука         450
# 221      5258  2024-06-11    Київ  Квантова фізика  Наука         450
# 229      5345  2024-07-23  Дніпро  Квантова фізика  Наука         450
# 236      5190  2024-04-04   Львів  Квантова фізика  Наука         450
#
#      quantity  discount_pct   total               channel  ... full_price  \
# 29          1             0   450.0               Телефон  ...        450
# ...

# %% [markdown]
# **Завдання 109.** Відсортуйте таблицю за кількістю книг (`quantity`) за спаданням. Виведіть перші 5.

# %%
# Завдання 109:
df.sort_values(["quantity"], ascending=False ).head(5)
# Out:
#      order_id        date    city              book_title       genre  \
# 360      5377  2024-08-13  Дніпро  Гордість і упередження   Романтика
# 20       5165  2024-04-14  Харків                    Дюна  Фантастика
# 343      5272  2024-06-25   Львів                  Кобзар      Поезія
# 42       5130  2024-03-04  Харків  Гордість і упередження   Романтика
# 249      5365  2024-08-26    Київ         Квантова фізика       Наука
#
#      unit_price  quantity  discount_pct   total  channel  ... full_price  \
# 360         240         5             0  1200.0     Сайт  ...       1200
# 20          320         5            10  1440.0  Телефон  ...       1600
# 343         180         5             5   855.0  Телефон  ...        900
# 42          240         5             0  1200.0     Сайт  ...       1200
# 249         450         5             0  2250.0     Сайт  ...       2250
#
#      discount_amount  price_with_tax  is_big  is_discauntet  \
# ...

# %% [markdown]
# **Завдання 110.** Відсортуйте таблицю за оцінкою (`rating`) за зростанням. Виведіть перші 5.

# %%
# Завдання 110:
df.sort_values(["rating"], ascending=True ).head(5)
# Out:
#      order_id        date    city              book_title      genre  \
# 27       5307  2024-07-13  Дніпро    Тіні забутих предків    Історія
# 376      5245  2024-05-18    Київ  Гордість і упередження  Романтика
# 381      5047  2024-01-04   Львів  Гордість і упередження  Романтика
# 379      5049  2024-01-22  Дніпро            Лісова пісня     Поезія
# 356      5046  2024-01-25   Одеса             Сила звички     Бізнес
#
#      unit_price  quantity  discount_pct  total               channel  ...  \
# 27          220         3            10  594.0                  Сайт  ...
# 376         240         2             0  480.0                  Сайт  ...
# 381         240         2             0  480.0               Телефон  ...
# 379         150         1             0  150.0  Мобільний застосунок  ...
# 356         260         1             0  260.0                  Сайт  ...
#
#     full_price  discount_amount  price_with_tax  is_big  is_discauntet  \
# ...

# %% [markdown]
# **Завдання 111.** Знайдіть 3 найдорожчі замовлення (за `total`).
#
# > 💡 Відсортуйте за спаданням і візьміть head(3).

# %%
# Завдання 111:
df.sort_values(["total"], ascending=False).head(3)

# %% [markdown]
# **Завдання 112.** Знайдіть 3 найдешевші замовлення (за `total`).

# %%
# Завдання 112:
df.sort_values(["total"], ascending=True).head(3)
# Out:
#      order_id        date    city       book_title   genre  unit_price  \
# 342      5289  2024-06-10  Дніпро  Маленький принц  Дитяча         160
# 133      5140  2024-03-23   Одеса  Маленький принц  Дитяча         160
# 315      5128  2024-03-14  Харків  Маленький принц  Дитяча         160
# 379      5049  2024-01-22  Дніпро     Лісова пісня  Поезія         150
# 308      5155  2024-04-16   Одеса     Лісова пісня  Поезія         150
# ..        ...         ...     ...              ...     ...         ...
# 396      5129  2024-03-21  Харків          Sapiens   Наука         410
# 234      5246  2024-05-17  Харків          Sapiens   Наука         410
# 200      5183  2024-04-07   Львів          Sapiens   Наука         410
# 249      5365  2024-08-26    Київ  Квантова фізика   Наука         450
# 84       5132  2024-03-23    Київ  Квантова фізика   Наука         450
#
#      quantity  discount_pct   total               channel  ... full_price  \
# ...

# %% [markdown]
# ## Розділ 9. Групування — groupby (завдання 113-120)
#
# Схема: `df.groupby("стовпець")["що_рахувати"].агрегат()`.

# %% [markdown]
# **Завдання 113.** Порахуйте загальну виручку (`total`) по кожному місту.
#
# > 💡 df.groupby("city")["total"].sum().

# %%
# Завдання 113:
df.groupby("city")["total"].sum()
# Out:
# city
# Дніпро    35781.5
# Київ      37325.5
# Львів     50604.5
# Одеса     48088.5
# Харків    57002.0
# Name: total, dtype: float64

# %% [markdown]
# **Завдання 114.** Порахуйте середню суму замовлення по кожному жанру.
#
# > 💡 groupby genre, потім mean().

# %%
# Завдання 114:
df.groupby("genre")["total"].sum()
# Out:
# genre
# Історія       28312.0
# Бізнес        34612.0
# Детектив      25490.5
# Дитяча        21273.5
# Наука         55382.5
# Поезія        16927.5
# Романтика     16236.0
# Фантастика    30568.0
# Name: total, dtype: float64

# %% [markdown]
# **Завдання 115.** Порахуйте кількість замовлень по кожному менеджеру.
#
# > 💡 groupby manager, потім count() на якомусь стовпці.

# %%
# Завдання 115:
df.groupby("manager")["order_id"].count()
# Out:
# manager
# Ірина     77
# Віктор    75
# Наталя    79
# Олег      80
# Софія     89
# Name: order_id, dtype: int64

# %% [markdown]
# **Завдання 116.** Порахуйте загальну кількість проданих книг (`quantity`) по кожному жанру.

# %%
# Завдання 116:
df.groupby("genre")["quantity"].sum()
# Out:
# genre
# Історія        99
# Бізнес        128
# Детектив      100
# Дитяча         88
# Наука         130
# Поезія        105
# Романтика      68
# Фантастика    105
# Name: quantity, dtype: int64

# %% [markdown]
# **Завдання 117.** Порахуйте середню оцінку (`rating`) по кожному каналу (`channel`).

# %%
# Завдання 117:
df.groupby("channel")["rating"].mean()
# Out:
# channel
# Мобільний застосунок    4.207407
# Сайт                    4.338710
# Телефон                 4.226950
# Name: rating, dtype: float64

# %% [markdown]
# **Завдання 118.** Знайдіть загальну виручку по жанрах і відсортуйте за спаданням.
#
# > 💡 Після groupby().sum() додайте .sort_values(ascending=False).

# %%
# Завдання 118:
df.groupby("genre")["total"].sum().sort_values(ascending=False)
# Out:
# genre
# Наука         55382.5
# Бізнес        34612.0
# Фантастика    30568.0
# Історія       28312.0
# Детектив      25490.5
# Дитяча        21273.5
# Поезія        16927.5
# Романтика     16236.0
# Name: total, dtype: float64

# %% [markdown]
# **Завдання 119.** Порахуйте середню, мінімальну і максимальну суму замовлення по містах.
#
# > 💡 Використайте .agg(["mean", "min", "max"]).

# %%
# Завдання 119:
df.groupby("city")["total"].agg(["mean", "min", "max"]).round(2)
# Out:
#           mean    min     max
# city
# Дніпро  518.57  128.0  1640.0
# Київ    548.90  160.0  2250.0
# Львів   609.69  150.0  2050.0
# Одеса   586.45  136.0  1600.0
# Харків  581.65  144.0  2050.0

# %% [markdown]
# **Завдання 120.** Порахуйте загальну виручку по двох стовпцях одночасно: місто і жанр.
#
# > 💡 groupby(["city", "genre"]).

# %%
# Завдання 120:
df.groupby(["city", "genre"])["total"].sum()
# Out:
# city    genre
# Дніпро  Історія        3061.0
#         Бізнес         3680.5
#         Детектив       4044.5
#         Дитяча         3265.0
#         Наука         10159.5
#         Поезія         1539.0
#         Романтика      4320.0
#         Фантастика     5712.0
# Київ    Історія        4052.0
#         Бізнес         4273.5
#         Детектив       5805.0
#         Дитяча         4592.0
#         Наука          9740.0
#         Поезія         3075.0
#         Романтика      1428.0
#         Фантастика     4360.0
# Львів   Історія        6286.0
#         Бізнес         5749.5
#         Детектив       5510.5
#         Дитяча         4996.5
#         Наука         14302.5
#         Поезія         5977.5
#         Романтика      3360.0
#         Фантастика     4422.0
# Одеса   Історія        7536.0
#         Бізнес        13935.5
#         Детектив       3845.0
#         Дитяча         4513.5
#         Наука          6229.5
#         Поезія         2631.0
# ...

# %%
book_sales_of_genre = df.groupby(["city", "genre"])["total"].sum().unstack(fill_value=0)
book_sales
# Out:
# genre   Історія   Бізнес  Детектив  Дитяча    Наука  Поезія  Романтика  \
# city
# Дніпро   3061.0   3680.5    4044.5  3265.0  10159.5  1539.0     4320.0
# Київ     4052.0   4273.5    5805.0  4592.0   9740.0  3075.0     1428.0
# Львів    6286.0   5749.5    5510.5  4996.5  14302.5  5977.5     3360.0
# Одеса    7536.0  13935.5    3845.0  4513.5   6229.5  2631.0     1680.0
# Харків   7377.0   6973.0    6285.5  3906.5  14951.0  3705.0     5448.0
#
# genre   Фантастика
# city
# Дніпро      5712.0
# Київ        4360.0
# Львів       4422.0
# Одеса       7718.0
# Харків      8356.0

# %% [markdown]
# ---
#
# # 🎉 Готово!
#
# Якщо ви пройшли всі 120 завдань — вітаємо! Ви відпрацювали весь базовий синтаксис pandas:
#
# - ✅ Перший погляд на дані (`head`, `tail`, `shape`, `info`, `describe`)
# - ✅ Вибір стовпців
# - ✅ Агрегати (`sum`, `mean`, `max`, `min`, `unique`, `value_counts`, `nunique`)
# - ✅ Фільтрація (одна умова та кілька умов)
# - ✅ Створення нових стовпців
# - ✅ Сортування
# - ✅ Групування (`groupby`)
#
# ### Порада
# Найкращий спосіб закріпити — повернутись через кілька днів і пройти завдання ще раз, не підглядаючи. Те, що спочатку вимагало роздумів, стане автоматичним.
#
# **Так тримати! 🐼**
